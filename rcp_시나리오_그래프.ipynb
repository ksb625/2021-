# %%
import pandas as pd
import io
from google.colab import files
myfile1 = files.upload() 
myfile2 = files.upload() 
myfile3 = files.upload() 
myfile4 = files.upload()
# Out:
#      <input type="file" id="files-47b7a082-9f20-49bc-a23e-05f246f28b97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47b7a082-9f20-49bc-a23e-05f246f28b97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving RCP 2.6.csv to RCP 2.6 (1).csv
#      <input type="file" id="files-7969270e-b589-4f98-955f-cdb69298b892" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7969270e-b589-4f98-955f-cdb69298b892">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving RCP 4.5.csv to RCP 4.5 (1).csv
# ...

# %%
df_1=pd.read_csv(io.BytesIO(myfile1['RCP 2.6.csv']), encoding='utf-8')
df_2=pd.read_csv(io.BytesIO(myfile2['RCP 4.5.csv']), encoding='utf-8')
df_3=pd.read_csv(io.BytesIO(myfile3['RCP 6.0.csv']), encoding='utf-8')
df_4=pd.read_csv(io.BytesIO(myfile4['RCP 8.5.csv']), encoding='utf-8')

# %%
df_1 = df_1.set_index("년도")
df_2 = df_2.set_index("년도")
df_3 = df_3.set_index("년도")
df_4 = df_4.set_index("년도")

# %%
# !apt -qq -y install fonts-nanum > /dev/null 
 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm 
 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font = fm.FontProperties(fname=fontpath, size=10) 
fm._rebuild()
99
# %config InlineBackend.figure_format = 'retina'

plt.rc('font', family='NanumBarunGothic')
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
df_1.columns=['RCP 2.6']
df_2.columns=['RCP 4.5']
df_3.columns=['RCP 6.0']
df_4.columns=['RCP 8.5']

# %%
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm

# %%
result= pd.concat([df_1,df_2,df_3,df_4],axis=1)

# %%
df_1.plot()
plt.axhline(12.6211, 0, 1, color='orange', linestyle='--', linewidth=2)

# %%
df_2.plot()
plt.axhline(12.6211, 0, 1, color='orange', linestyle='--', linewidth=2)

# %%
df_3.plot()
plt.axhline(13.3186, 0, 1, color='orange', linestyle='--', linewidth=2)

# %%
df_4.plot()
plt.axhline(13.8046, 0, 1, color='orange', linestyle='--', linewidth=2)

# %%
result
# Out:
#       RCP 2.6  RCP 4.5  RCP 6.0  RCP 8.5
# 년도
# 2021  12.1408  11.1211  11.3186  11.8046
# 2022  12.4092  11.3396  11.1735  11.6644
# 2023  12.6726  12.8788  11.4356  11.2801
# 2024  13.1128  12.2378  11.0462  11.6562
# 2025  11.7255  12.0079  10.8317  12.1916
# ...       ...      ...      ...      ...
# 2096  12.8357  13.8950  14.6964  14.9698
# 2097  13.1231  14.1141  14.6164  14.9810
# 2098  12.9802  13.9397  14.1557  16.5899
# 2099  13.5316  13.9922  14.1545  16.3223
# 2100  12.5512  13.7307  15.2078  16.1731
#
# [80 rows x 4 columns]

# %%
result.plot()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
