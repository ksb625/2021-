# %%
import pandas as pd
import io
import matplotlib.pyplot as plt

# %%
from google.colab import files
myfile = files.upload()  #파일 업로드(last.csv)
# Out:
#      <input type="file" id="files-c65480fb-6748-49dd-9062-a04e08885a99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c65480fb-6748-49dd-9062-a04e08885a99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving last.csv to last.csv

# %%
df = pd.read_csv(io.BytesIO(myfile['last.csv']), encoding='utf-8')

# %%
df
# Out:
#     set  value
# 0     1   1.14
# 1     2   1.24
# 2     3   1.17
# 3     4   0.97
# 4     5   1.01
# 5     6   0.87
# 6     7   0.90
# 7     8   0.87
# 8     9   0.97
# 9    10   1.24
# 10   11   0.98
# 11   12   1.11
# 12   13   1.04
# 13   14   1.06
# 14   15   1.26
# 15   16   1.05
# 16   17   0.88
# 17   18   1.06
# 18   19   1.21
# 19   20   1.13
# 20   21   1.55
# 21   22   1.25
# 22   23   0.99
# 23   24   1.20
# 24   25   1.04
# 25   26   1.09
# 26   27   1.21
# 27   28   1.31
# 28   29   1.21
# 29   30   1.40
# 30   31   1.22
# 31   32   1.19
# 32   33   1.15
# 33   34   1.26
# 34   35   1.11
# 35   36   1.25
# 36   37   1.59
# 37   38   1.71
# 38   39   1.67
# 39   40   1.41
# 40   41   1.28
# 41   42   1.14
# 42   43   1.11
# 43   44   1.14
# 44   45   1.21
# 45   46   1.23
# 46   47   1.62
# 47   48   1.24
# 48   49   1.36
# 49   50   1.38
# 50   51   1.57
# 51   52   1.45
# 52   53   1.13
# 53   54   1.35

# %%
df= df.set_index("set")

# %%
from matplotlib import pyplot
df.plot()
plt.ylim([-0.5, 2])  
plt.axhline(0, 0, 1, color='orange', linestyle='--', linewidth=2)
pyplot.show()
